# %%
import matplotlib.pyplot as plt
import ast

# Read the data from the text file
with open("output/taskTwo.txt") as f:
    data_string = f.read()

# Convert the string into a Python list using ast.literal_eval
data = ast.literal_eval(data_string)

plt.figure()
nums = []
names = []
# for accessing the required data for plotting
for item in data:
  nums.append(item[1])
  names.append('{}-{}'.format(item[0][0], item[0][1]))
# plotting
plt.bar(names, nums, width=0.8)
plt.ylabel('trip counts')
plt.xlabel('business-month')
plt.title('number of trips for each business in each month')
# Out:
# Text(0.5, 1.0, 'number of trips for each business in each month')

# %%
import json
python_list = json.loads("output/taskTwo")
python_list
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[11], line 2
#       1 import json
# ----> 2 python_list = json.loads("output/taskTwo")
#       3 python_list
#
# File /opt/conda/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /opt/conda/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
# ...
