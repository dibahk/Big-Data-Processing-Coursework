# %% [markdown]
# # Task 2
#
# ## part 1
#
# plotting the number of trips for each business in each month

# %%
import matplotlib.pyplot as plt
import ast

# Read the data from the text file
with open("output/taskTwo_1.txt") as f:
    data_string = f.read()

# Convert the string into a Python list using ast.literal_eval
data = ast.literal_eval(data_string)

plt.figure(figsize=(12,8))
nums = []
names = []
# for accessing the required data for plotting
for item in data:
  nums.append(item[1])
  names.append('{}-{}'.format(item[0][0], item[0][1]))
# plotting
bars = plt.bar(names, nums, width=0.4)
plt.ylabel('trip counts')
plt.xlabel('business-month')
plt.title('number of trips for each business in each month')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x(), yval + .005, '{:.2f}'.format(yval))

# %% [markdown]
# ## Part 2
#
# plotting platform's profits (rideshare_profit field) for each business in each month

# %%
import matplotlib.pyplot as plt
import ast

# Read the data from the text file
with open("output/taskTwo_2.txt") as f:
    data_string = f.read()

# Convert the string into a Python list using ast.literal_eval
data = ast.literal_eval(data_string)

plt.figure(figsize=(15,8))
nums = []
names = []
# for accessing the required data for plotting
for item in data:
  nums.append(item[1])
  names.append('{}-{}'.format(item[0][0], item[0][1]))
# plotting
bars = plt.bar(names, nums, width=0.8)
plt.ylabel('trip counts')
plt.xlabel("platform's profits")
plt.title("platform's profits (rideshare_profit field) for each business in each month")
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x(), yval + .005, '{:.2f}'.format(yval))

# %% [markdown]
# ## Part 3
#
# plotting  driver's earnings (driver_total_pay field) for each business in each month

# %%
import matplotlib.pyplot as plt
import ast

# Read the data from the text file
with open("output/taskTwo_3.txt") as f:
    data_string = f.read()

# Convert the string into a Python list using ast.literal_eval
data = ast.literal_eval(data_string)

plt.figure(figsize=(15,8))
nums = []
names = []
# for accessing the required data for plotting
for item in data:
  nums.append(item[1])
  names.append('{}-{}'.format(item[0][0], item[0][1]))
# plotting
bars = plt.bar(names, nums, width=0.8)
plt.ylabel('trip counts')
plt.xlabel("driver's earnings")
plt.title("driver's earnings (driver_total_pay field) for each business in each month")
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x(), yval + .005, '{:.2f}'.format(yval))

# %% [markdown]
# # Task 5
#
# # 1
#
# plotting average waiting time over time

# %%
import matplotlib.pyplot as plt
import ast

# Read the data from the text file
with open("output/taskFive_1.txt") as f:
    data_string = f.read()

# Convert the string into a Python list using ast.literal_eval
data = ast.literal_eval(data_string)
# defining the size of the plot
plt.figure(figsize=(15,8))
days = []
avg_wait = []
# for accessing the required data for plotting
for item in data:
  days.append(item[0])
  avg_wait.append(item[1])
# plotting
bars = plt.bar(days, avg_wait)
plt.xlabel('days')
plt.ylabel("average waiting time")
plt.title("average waiting time over time")
plt.xticks(days)
# Out:
# ([<matplotlib.axis.XTick at 0x7f124ee719c0>,
# ...
#  [Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17'),
#   Text(18, 0, '18'),
#   Text(19, 0, '19'),
#   Text(20, 0, '20'),
#   Text(21, 0, '21'),
#   Text(22, 0, '22'),
#   Text(23, 0, '23'),
#   Text(24, 0, '24'),
#   Text(25, 0, '25'),
#   Text(26, 0, '26'),
#   Text(27, 0, '27'),
#   Text(28, 0, '28'),
#   Text(29, 0, '29'),
#   Text(30, 0, '30'),
#   Text(31, 0, '31')])
